# %% [markdown]
# Import libraries

# %%
# %load_ext autoreload
# %autoreload 2

from bimpy import bSimpleStack

# %matplotlib notebook

from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
path = '/Users/cudmore/box/data/nathan/vesselucida/20191017__0001.tif'

bss = bSimpleStack.bSimpleStack(path)
# Out:
# bSimpleStack.loadStack() loading path: /Users/cudmore/box/data/nathan/vesselucida/20191017__0001.tif
#    self._images.shape: (145, 640, 640)
#    self._images.dtype: uint16
#    min: 17
#    max: 4095
# bSlabList warning, did not find slabFilePath: /Users/cudmore/box/data/nathan/vesselucida/20191017__0001_slabs.txt
# loadVesselucida_xml() loaded 87 nodes and 181 edges from xml file /Users/cudmore/box/data/nathan/vesselucida/20191017__0001.xml

# %%
x = bss.slabList.x
y = bss.slabList.y
z = bss.slabList.z

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

'''
plt.plot(x, y, z)
plt.title('A simple chirp');
'''

ax.scatter(x,y,z)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# convex hull
from scipy.spatial import ConvexHull
import numpy as np

x = bss.slabList.orig_x
y = bss.slabList.orig_y
z = bss.slabList.orig_z
points = np.column_stack((x,y,z))

#see: https://docs.scipy.org/doc/scipy/reference/generated/scipy.spatial.ConvexHull.html
hull = ConvexHull(points)

print(hull.volume)
