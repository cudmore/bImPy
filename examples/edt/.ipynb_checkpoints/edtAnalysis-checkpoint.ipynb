# %% [markdown]
# ## Analyze the output of the hcn1 edt
#
# The hcn1 edt gives us the distance of each pixel in the hcn1 mask to the nearest vascular mask pixel (in um)

# %%
import os

import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels

import tifffile

# %% [markdown]
# ## Utility functions

# %%
def myLabelSize(g, myFontSize=22):
    """
    g: return of seaborn plot function
    """
    g.set_xlabel(g.get_xlabel(), size = myFontSize)
    g.set_ylabel(g.get_ylabel(), size = myFontSize)
    #
    g.set_xticklabels(g.get_xticks(), size = myFontSize)
    g.set_yticklabels(g.get_yticks(), size = myFontSize)

    # yticklabels were sometimes blowing up into 1.000000000001
    ylabels = [str(round(y,1)) for y in g.get_yticks()] # used below
    g.set_yticklabels(ylabels, size = myFontSize) # using from above

def printStackInfo(name, data):
    print('stack', filename, 
          stackData.shape, 
          stackData.dtype, 
          'min:', np.nanmin(stackData), 
          'max:', np.nanmax(stackData), 
          'mean:', np.nanmean(stackData))
    
def myLegend(g):
    g.legend()
    plt.setp(ax.get_legend().get_texts(), fontsize='22') # for legend text
    plt.setp(ax.get_legend().get_title(), fontsize='32') # for legend title

# %% [markdown]
# ## Load hcn1 edt

# %%
# load a list

legendList = [
    'distalHead',
    'head',
    'mid'
]

pathList = [
    '/Users/cudmore/box/data/nathan/20200420/analysis/20200420_distalHEAD__ch1_9_edt.tif',
    '/Users/cudmore/box/data/nathan/20200420/analysis/20200420_HEAD__ch1_9_edt.tif',
    '/Users/cudmore/box/data/nathan/20200420/analysis/20200420_MID__ch1_9_edt.tif',
]

stackDataList = []
for path in pathList:
    stackData = tifffile.imread(path)

    filename = os.path.basename(path)
    printStackInfo(filename, stackData)

    stackDataList.append(stackData)
# Out:
# stack 20200420_distalHEAD__ch1_9_edt.tif (26, 1024, 1024) float32 min: 0.0 max: 49.71332 mean: 11.911905
# stack 20200420_HEAD__ch1_9_edt.tif (36, 1024, 1024) float32 min: 0.0 max: 75.18001 mean: 8.928503
# stack 20200420_MID__ch1_9_edt.tif (23, 1024, 1024) float32 min: 0.0 max: 70.23193 mean: 10.07037

# %%
sns.set(style="ticks", context="talk")
plt.style.use("dark_background")

# %% [markdown]
# ## Plot raw edt distances as a histogram
#
# We are doing this to show that 'really short' distances contaminate the measurement. These are pixels in hcn1 mask that are super close to a vessel. In this dataset there are some 200,000 of them.

# %%
fig, ax = plt.subplots(1, 1, sharey=False, figsize=(5,5))

stackData = stackDataList[0]

norm_hist = False

# histogrsm
g = sns.distplot(stackData, hist=True, kde=False, norm_hist=norm_hist, ax=ax)

# %% [markdown]
# ## Remove really short distances
#
# Rational, is these are pushing right up again a vessel and there are LOTS of them

# %%
# remove really short distances
removeLessThanUm = 1
print('removing distances <=', removeLessThanUm)
for idx, stackData in enumerate(stackDataList):
    stackData[stackData<=removeLessThanUm] = np.nan
    
    filename = os.path.basename(pathList[idx])
    printStackInfo(filename, stackData)

#
# plot again
fig, ax = plt.subplots(1, 1, sharey=False, figsize=(5,5))
stackData = stackDataList[0]
# histogrsm
g = sns.distplot(stackData, hist=True, kde=False, norm_hist=False, ax=ax)
# Out:
# removing distances <= 1
# /Users/cudmore/Sites/bImPy/bImPy_env/lib/python3.7/site-packages/ipykernel_launcher.py:5: RuntimeWarning: invalid value encountered in less_equal
#   """
# stack 20200420_distalHEAD__ch1_9_edt.tif (26, 1024, 1024) float32 min: 1.0111758 max: 49.71332 mean: 12.99995
# stack 20200420_HEAD__ch1_9_edt.tif (36, 1024, 1024) float32 min: 1.0015583 max: 75.18001 mean: 10.247228
# stack 20200420_MID__ch1_9_edt.tif (23, 1024, 1024) float32 min: 1.0111758 max: 70.23193 mean: 11.1082735

# %% [markdown]
#  ## Plot hcn1 edt histogram
#
# This is the distribution of distances (um) from each pixel in hcn1 mask to closest vascular mask.
#
# Looking at this tells me there may be a difference between (distalHead, head, mid) but we simply need more images to get an average !!!

# %%
fig, axs = plt.subplots(2, 1, sharey=False, figsize=(10,15))

hist = True
kde = True # kde: Whether to plot a gaussian kernel density estimate (if True ... VERY SLOW)
norm_hist = True

hist_kws = {
    'alpha':0.5, # set to 1 so colors do not 'sum'
    'cumulative':False
}
colorList = ['r', 'g', 'b']

# histogram
ax = axs[0]
for idx, stackData in enumerate(stackDataList):
    color = colorList[idx]
    label = legendList[idx]
    g = sns.distplot(stackData, hist=hist, kde=kde, norm_hist=norm_hist,
                     hist_kws=hist_kws, color=color, label=label, ax=ax)

#print('type(g):', type(g))
myLabelSize(g)
g.set(xlim=(None, 50))
g.set(xlabel='Distance To Vessel (um)')
myLegend(g)

# cumulative
kde = False
hist_kws = {
    'alpha':0.5, # set to 1 so colors do not 'sum'
    'cumulative':True
}
kde_kws = {
    'cumulative': False # THIS IS SUPER SUPER SLOW !!!
}

ax = axs[1]
for idx, stackData in enumerate(stackDataList):
    color = colorList[idx]
    label = legendList[idx]
    g = sns.distplot(stackData, hist=hist, kde_kws=kde_kws, norm_hist=norm_hist,
                     hist_kws=hist_kws, color=color, label=label, ax=ax)

myLabelSize(g)
g.set(xlim=(None, 50))
g.set(xlabel='Distance To Vessel (um)')
myLegend(g)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-103e5e5135f1> in <module>
#      40     label = legendList[idx]
#      41     g = sns.distplot(stackData, hist=hist, kde_kws=kde_kws, norm_hist=norm_hist,
# ---> 42                      hist_kws=hist_kws, color=color, label=label, ax=ax)
#      43
#      44 myLabelSize(g)
#
# ~/Sites/bImPy/bImPy_env/lib/python3.7/site-packages/seaborn/distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     226     if kde:
#     227         kde_color = kde_kws.pop("color", color)
# --> 228         kdeplot(a, vertical=vertical, ax=ax, color=kde_color, **kde_kws)
#     229         if kde_color != color:
#     230             kde_kws["color"] = kde_color
#
# ~/Sites/bImPy/bImPy_env/lib/python3.7/site-packages/seaborn/distributions.py in kdeplot(data, data2, shade, vertical, kernel, bw, gridsize, cut, clip, legend, cumulative, shade_lowest, cbar, cbar_ax, cbar_kws, ax, **kwargs)
#     700         ax = _univariate_kdeplot(data, shade, vertical, kernel, bw,
#     701                                  gridsize, cut, clip, legend, ax,
# --> 702                                  cumulative=cumulative, **kwargs)
#     703
#     704     return ax
#
# ~/Sites/bImPy/bImPy_env/lib/python3.7/site-packages/seaborn/distributions.py in _univariate_kdeplot(data, shade, vertical, kernel, bw, gridsize, cut, clip, legend, ax, cumulative, **kwargs)
#     288         x, y = _statsmodels_univariate_kde(data, kernel, bw,
#     289                                            gridsize, cut, clip,
# --> 290                                            cumulative=cumulative)
#     291     else:
#     292         # Fall back to scipy if missing statsmodels
#
# ~/Sites/bImPy/bImPy_env/lib/python3.7/site-packages/seaborn/distributions.py in _statsmodels_univariate_kde(data, kernel, bw, gridsize, cut, clip, cumulative)
#     371
#     372     if cumulative:
# --> 373         grid, y = kde.support, kde.cdf
#     374     else:
#     375         grid, y = kde.support, kde.density
#
# pandas/_libs/properties.pyx in pandas._libs.properties.CachedProperty.__get__()
#
# ~/Sites/bImPy/bImPy_env/lib/python3.7/site-packages/statsmodels/nonparametric/kde.py in cdf(self)
#     176         endog = self.endog
#     177         probs = [integrate.quad(func, support[i - 1], support[i],
# --> 178                     args=endog)[0] for i in range(1, gridsize)]
#     179         return np.cumsum(probs)
#     180
#
# ~/Sites/bImPy/bImPy_env/lib/python3.7/site-packages/statsmodels/nonparametric/kde.py in <listcomp>(.0)
#     176         endog = self.endog
#     177         probs = [integrate.quad(func, support[i - 1], support[i],
# --> 178                     args=endog)[0] for i in range(1, gridsize)]
#     179         return np.cumsum(probs)
#     180
#
# ~/Sites/bImPy/bImPy_env/lib/python3.7/site-packages/scipy/integrate/quadpack.py in quad(func, a, b, args, full_output, epsabs, epsrel, limit, points, weight, wvar, wopts, maxp1, limlst)
#     340     if weight is None:
#     341         retval = _quad(func, a, b, args, full_output, epsabs, epsrel, limit,
# --> 342                        points)
#     343     else:
#     344         if points is not None:
#
# ~/Sites/bImPy/bImPy_env/lib/python3.7/site-packages/scipy/integrate/quadpack.py in _quad(func, a, b, args, full_output, epsabs, epsrel, limit, points)
#     451     if points is None:
#     452         if infbounds == 0:
# --> 453             return _quadpack._qagse(func,a,b,args,full_output,epsabs,epsrel,limit)
#     454         else:
#     455             return _quadpack._qagie(func,bound,infbounds,args,full_output,epsabs,epsrel,limit)
#
# ~/Sites/bImPy/bImPy_env/lib/python3.7/site-packages/statsmodels/nonparametric/kde.py in <lambda>(x, s)
#     169         else:
#     170             a,b = kern.domain
# --> 171         func = lambda x,s: kern.density(s,x)
#     172
#     173         support = self.support
#
# ~/Sites/bImPy/bImPy_env/lib/python3.7/site-packages/statsmodels/sandbox/nonparametric/kernels.py in density(self, xs, x)
#     202                 w = 1 / h * np.sum(self((xs-x)/h).T * weights, axis=1)
#     203             else:
# --> 204                 w = 1. / (h * n) * np.sum(self((xs-x)/h), axis=0)
#     205             return w
#     206         else:
#
# ~/Sites/bImPy/bImPy_env/lib/python3.7/site-packages/statsmodels/sandbox/nonparametric/kernels.py in __call__(self, x)
#     407         Does the same as weight if the function is normalised
#     408         """
# --> 409         return self._shape(x)
#     410
#     411
#
# ~/Sites/bImPy/bImPy_env/lib/python3.7/site-packages/statsmodels/sandbox/nonparametric/kernels.py in <lambda>(x)
#     518     def __init__(self, h=1.0):
#     519         CustomKernel.__init__(self, shape = lambda x: 0.3989422804014327 *
# --> 520                         np.exp(-x**2/2.0), h = h, domain = None, norm = 1.0)
#     521         self._L2Norm = 1.0/(2.0*np.sqrt(np.pi))
#     522         self._kernel_var = 1.0
#
# KeyboardInterrupt:
